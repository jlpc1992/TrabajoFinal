# %% [markdown]
# <center><h1 Style="color:#1E30FF">Proyecto de disminución de contaminación</h1></center>
# <center><h5>Universidad Castro Carazo</h5></center>
# <center><h6>2C - 2022</h6></center>
# <center><h6>JOSE LUIS PEÑALOZA CASTAÑEDA</h6></center>
# </br>
# </br>
# <p Style="text-align: justify" >Este notebook contiene el analisis de los datos del Sistema Nacional de Metrica de Cambio Climático para Costa Rica, el análisis se realiza para buscar responder la siguiente pregunta: ¿Como se puede disminuir el nivel de contaminación en Costa Rica?
# Para esto se realiza un analisis del conjunto de datos obtenido de la página de SINAMECC.
# </br>
# </br>
# <a href="http://sinamecc.opendata.junar.com/dashboards/21304/balance-nacional-de-energia-bne-prop-estr/">Fuente de datos para el analisis</a>

# %% [markdown]
# <p Style="text-align: justify" >A continuación se presenta los pasos a seguir en proyecto realizado.
#
# <h2 Style="color:#1E90FF">1 Carga y estandarización de los set de datos</h2></center>
# </br>
# <p>Que se hace en esta etapa</p>
# <ol>
#     <li>Importar las librerias necesarias</li>
#     <li>Importar el los set de datos</li>
#     <li>Revisar los encabezados de los dataframe</li>
#     <li>Si solo si tenemos más de un set de datos, se unen los set de datos en un único dataframe</li>

# %% [markdown]
# <h5>1.1 Importar las librerias</h5></center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl

# %% [markdown]
# <h5>1.2 Importar el set de datos</h5></center>

# %%
df_1ro_energia = pd.read_csv("Total consumo por tipo de fuente (Terajoules).csv")
df_2do_energia = pd.read_csv("Total generación eléctrica por tipo de fuente (TJ).csv")
df_3ro_energia = pd.read_csv("Total importaciones de energía (Terajoules).csv")

# %%
df_1ro_energia
# Out:
#       Año Carbón Mineral      Coque        Leña     Bagazo Otros Res. Veg.  \
# 0    2010          29.89   2,675.36   13,998.14   9,836.32        4,395.70
# 1    2011         229.20   3,717.92   12,839.58   7,729.44        4,448.78
# 2    2012          91.97   3,382.79   12,161.88   8,088.95        4,385.46
# 3    2013         204.32   3,359.27   12,059.79   9,864.93        4,161.97
# 4    2014         248.10   3,288.28   11,066.46  10,318.32        4,360.37
# 5    2015          14.00   3,211.70   10,825.70  10,072.36        3,789.58
# 6    2016          13.51   3,493.96   10,170.89  10,072.36        3,742.20
# 7    2017         214.02   3,786.46   10,211.16   9,359.19        3,329.99
# 8    2018          13.87   3,534.58    8,603.49   9,134.57        3,224.83
# 9    2019          10.19   1,728.44    8,582.54   9,060.66        3,258.67
# 10  Total       1,069.07  32,178.76  110,519.63  93,537.10       39,097.55
#
#     Carbón Vegetal Casc. de Café Biogas Electricidad      G.L.P  \
# ...

# %%
df_1ro_energia.shape
# Out:
# (11, 20)

# %%
df_2do_energia
# Out:
#       Año       Hidro Geotérmica     Eólica   Biomasa   Solar    Térmica  \
# 0    2010   26,144.25   4,233.89   1,291.23    521.41    0.93   2,308.23
# 1    2011   25,684.64   4,606.35   1,492.11    500.37    1.73   3,108.03
# 2    2012   26,039.52   5,049.18   1,902.18    643.04    4.67   2,989.02
# 3    2013   24,663.76   5,460.25   1,744.45    659.94    8.80   4,305.59
# 4    2014   24,181.75   5,537.29   2,645.11    650.24    8.88   3,755.53
# 5    2015   29,039.71   4,952.26   3,886.23    645.38    9.12     389.23
# 6    2016   28,893.40   4,822.25   4,130.25    617.42    8.69     694.89
# 7    2017   31,237.06   4,024.20   4,635.64    664.24   16.03     134.70
# 8    2018   30,034.43   3,486.85   6,475.95    625.19  201.76     570.78
# 9    2019   28,175.98   5,445.27   6,466.84    608.57  215.35     344.29
# 10  Total  274,094.50  47,617.79  34,669.99  6,135.80  475.96  18,600.29
#
#          Total
# 0    34,499.95
# 1    35,393.24
# 2    36,627.60
# 3    36,842.78
# ...

# %%
df_2do_energia.shape
# Out:
# (11, 8)

# %%
df_3ro_energia
# Out:
#       Año Importaciones (TJ)
# 0    2010         104,818.94
# 1    2011         105,991.40
# 2    2012         105,521.89
# 3    2013         108,967.28
# 4    2014         112,928.31
# 5    2015         107,389.30
# 6    2016         115,170.04
# 7    2017         122,745.30
# 8    2018         117,521.10
# 9    2019         123,790.75
# 10  Total       1,124,844.31

# %%
df_3ro_energia.shape
# Out:
# (11, 2)

# %% [markdown]
# <h5>1.3 Revisar encabezados de los set de datos</h5></center>

# %%
df_1ro_energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               11 non-null     object
#  1   Carbón Mineral    11 non-null     object
#  2   Coque             11 non-null     object
#  3   Leña              11 non-null     object
#  4   Bagazo            11 non-null     object
#  5   Otros Res. Veg.   11 non-null     object
#  6   Carbón Vegetal    11 non-null     float64
#  7   Casc. de Café     11 non-null     object
#  8   Biogas            11 non-null     object
#  9   Electricidad      11 non-null     object
#  10  G.L.P             11 non-null     object
#  11  Gasolina Regular  11 non-null     object
#  12  Gasolina Súper    11 non-null     object
#  13  Kerosene          11 non-null     object
#  14  Jet Fuel          11 non-null     object
#  15  Av-Gas            11 non-null     float64
# ...

# %%
df_2do_energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Año         11 non-null     object
#  1   Hidro       11 non-null     object
#  2   Geotérmica  11 non-null     object
#  3   Eólica      11 non-null     object
#  4   Biomasa     11 non-null     object
#  5   Solar       11 non-null     float64
#  6   Térmica     11 non-null     object
#  7   Total       11 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 832.0+ bytes

# %%
df_3ro_energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Año                 11 non-null     object
#  1   Importaciones (TJ)  11 non-null     object
# dtypes: object(2)
# memory usage: 304.0+ bytes

# %%
df_1ro_energia.columns
# Out:
# Index(['Año', 'Carbón Mineral', 'Coque', 'Leña', 'Bagazo', 'Otros Res. Veg.',
#        'Carbón Vegetal', 'Casc. de Café', 'Biogas', 'Electricidad', 'G.L.P',
#        'Gasolina Regular', 'Gasolina Súper', 'Kerosene', 'Jet Fuel', 'Av-Gas',
#        'Diesel', 'Gasoleo', 'Fuel Oil', 'Total'],
#       dtype='object')

# %%
df_2do_energia.columns
# Out:
# Index(['Año', 'Hidro', 'Geotérmica', 'Eólica', 'Biomasa', 'Solar', 'Térmica',
#        'Total'],
#       dtype='object')

# %%
df_3ro_energia.columns
# Out:
# Index(['Año', 'Importaciones (TJ)'], dtype='object')

# %% [markdown]
# <h5>1.4 Unir archivos en un solo dataframe </h5></center>
#
# </br>
# <p>El resultado al unir los dataframe por medio de pd.concat es una cantidad grande de daos erroneos porque las columnas de los dataframe no son inguales, se opta por trabajar añadiendo columnas por que hay coincidencia en cantidad de filas, y en el orden por columna de "Año" en los 3 set de datos.</p>

# %%
df_2do_energia["Hidro"]
# Out:
# 0      26,144.25
# 1      25,684.64
# 2      26,039.52
# 3      24,663.76
# 4      24,181.75
# 5      29,039.71
# 6      28,893.40
# 7      31,237.06
# 8      30,034.43
# 9      28,175.98
# 10    274,094.50
# Name: Hidro, dtype: object

# %%
df_1ro_energia.insert(1,"Hidro",["26,144.25","25,684.64","26,039.52","24,663.76","24,181.75","29,039.71","28,893.40","31,237.06","30,034.43","28,175.98","274,094.50"],True)
df_1ro_energia
# Out:
#       Año       Hidro Carbón Mineral      Coque        Leña     Bagazo  \
# 0    2010   26,144.25          29.89   2,675.36   13,998.14   9,836.32
# 1    2011   25,684.64         229.20   3,717.92   12,839.58   7,729.44
# 2    2012   26,039.52          91.97   3,382.79   12,161.88   8,088.95
# 3    2013   24,663.76         204.32   3,359.27   12,059.79   9,864.93
# 4    2014   24,181.75         248.10   3,288.28   11,066.46  10,318.32
# 5    2015   29,039.71          14.00   3,211.70   10,825.70  10,072.36
# 6    2016   28,893.40          13.51   3,493.96   10,170.89  10,072.36
# 7    2017   31,237.06         214.02   3,786.46   10,211.16   9,359.19
# 8    2018   30,034.43          13.87   3,534.58    8,603.49   9,134.57
# 9    2019   28,175.98          10.19   1,728.44    8,582.54   9,060.66
# 10  Total  274,094.50       1,069.07  32,178.76  110,519.63  93,537.10
#
#    Otros Res. Veg.  Carbón Vegetal Casc. de Café Biogas  ...      G.L.P  \
# ...

# %%
df_2do_energia["Geotérmica"]
# Out:
# 0      4,233.89
# 1      4,606.35
# 2      5,049.18
# 3      5,460.25
# 4      5,537.29
# 5      4,952.26
# 6      4,822.25
# 7      4,024.20
# 8      3,486.85
# 9      5,445.27
# 10    47,617.79
# Name: Geotérmica, dtype: object

# %%
df_1ro_energia.insert(1,"Geotérmica",df_2do_energia["Geotérmica"],True)
df_1ro_energia
# Out:
#       Año Geotérmica       Hidro Carbón Mineral      Coque        Leña  \
# 0    2010   4,233.89   26,144.25          29.89   2,675.36   13,998.14
# 1    2011   4,606.35   25,684.64         229.20   3,717.92   12,839.58
# 2    2012   5,049.18   26,039.52          91.97   3,382.79   12,161.88
# 3    2013   5,460.25   24,663.76         204.32   3,359.27   12,059.79
# 4    2014   5,537.29   24,181.75         248.10   3,288.28   11,066.46
# 5    2015   4,952.26   29,039.71          14.00   3,211.70   10,825.70
# 6    2016   4,822.25   28,893.40          13.51   3,493.96   10,170.89
# 7    2017   4,024.20   31,237.06         214.02   3,786.46   10,211.16
# 8    2018   3,486.85   30,034.43          13.87   3,534.58    8,603.49
# 9    2019   5,445.27   28,175.98          10.19   1,728.44    8,582.54
# 10  Total  47,617.79  274,094.50       1,069.07  32,178.76  110,519.63
#
#        Bagazo Otros Res. Veg.  Carbón Vegetal Casc. de Café  ...      G.L.P  \
# ...

# %%
df_1ro_energia.insert(1,"Eólica",df_2do_energia["Eólica"],True)
df_1ro_energia.insert(1,"Biomasa",df_2do_energia["Biomasa"],True)
df_1ro_energia.insert(1,"Solar",df_2do_energia["Solar"],True)
df_1ro_energia.insert(1,"Térmica",df_2do_energia["Térmica"],True)
df_1ro_energia.insert(1,"TotalGenElec",df_2do_energia["Total"],True)
df_1ro_energia
# Out:
#       Año TotalGenElec    Térmica   Solar   Biomasa     Eólica Geotérmica  \
# 0    2010    34,499.95   2,308.23    0.93    521.41   1,291.23   4,233.89
# 1    2011    35,393.24   3,108.03    1.73    500.37   1,492.11   4,606.35
# 2    2012    36,627.60   2,989.02    4.67    643.04   1,902.18   5,049.18
# 3    2013    36,842.78   4,305.59    8.80    659.94   1,744.45   5,460.25
# 4    2014    36,778.79   3,755.53    8.88    650.24   2,645.11   5,537.29
# 5    2015    38,921.94     389.23    9.12    645.38   3,886.23   4,952.26
# 6    2016    39,166.91     694.89    8.69    617.42   4,130.25   4,822.25
# 7    2017    40,711.86     134.70   16.03    664.24   4,635.64   4,024.20
# 8    2018    41,394.96     570.78  201.76    625.19   6,475.95   3,486.85
# 9    2019    41,256.29     344.29  215.35    608.57   6,466.84   5,445.27
# 10  Total   381,594.32  18,600.29  475.96  6,135.80  34,669.99  47,617.79
#
#          Hidro Carbón Mineral      Coque  ...      G.L.P Gasolina Regular  \
# ...

# %%
df_1ro_energia.insert(1,"Importaciones (TJ)",df_3ro_energia["Importaciones (TJ)"],True)
df_1ro_energia
# Out:
#       Año Importaciones (TJ) TotalGenElec    Térmica   Solar   Biomasa  \
# 0    2010         104,818.94    34,499.95   2,308.23    0.93    521.41
# 1    2011         105,991.40    35,393.24   3,108.03    1.73    500.37
# 2    2012         105,521.89    36,627.60   2,989.02    4.67    643.04
# 3    2013         108,967.28    36,842.78   4,305.59    8.80    659.94
# 4    2014         112,928.31    36,778.79   3,755.53    8.88    650.24
# 5    2015         107,389.30    38,921.94     389.23    9.12    645.38
# 6    2016         115,170.04    39,166.91     694.89    8.69    617.42
# 7    2017         122,745.30    40,711.86     134.70   16.03    664.24
# 8    2018         117,521.10    41,394.96     570.78  201.76    625.19
# 9    2019         123,790.75    41,256.29     344.29  215.35    608.57
# 10  Total       1,124,844.31   381,594.32  18,600.29  475.96  6,135.80
#
#        Eólica Geotérmica       Hidro Carbón Mineral  ...      G.L.P  \
# ...

# %% [markdown]
# <h2 Style="color:#1E90FF">2. Manejo de valores faltantes</h2>
# <p>Se deben trabajar los siguientes puntos</p>
# <ol>
#     <li>Identificar como se muestran los valores faltantes(null, espacio vacio, ?) y estandarizarlos a (NaN)</li>
#     <li>Contar la cantidad de valores NaN faltantes por variable(columna)</li>
#     <li>Analisis de imputación (el promedio / ML) para el caso de los numericos</li>
#     <li>Analisis de imputación (con el valor mas frecuente/ ML) para el caso de los caracteres</li>
#     <li>Eliminar filas o columas con valores faltantes</li>
# </ol>
# <h5>2.1 Identificar como se muestran los valores faltantes y estandarizarlos</h5>

# %% [markdown]
# <p>Se trabaja con un nombre simplificado para el nuevo set de datos</p>

# %%
df_energia=df_1ro_energia
df_energia
# Out:
#       Año Importaciones (TJ) TotalGenElec    Térmica   Solar   Biomasa  \
# 0    2010         104,818.94    34,499.95   2,308.23    0.93    521.41
# 1    2011         105,991.40    35,393.24   3,108.03    1.73    500.37
# 2    2012         105,521.89    36,627.60   2,989.02    4.67    643.04
# 3    2013         108,967.28    36,842.78   4,305.59    8.80    659.94
# 4    2014         112,928.31    36,778.79   3,755.53    8.88    650.24
# 5    2015         107,389.30    38,921.94     389.23    9.12    645.38
# 6    2016         115,170.04    39,166.91     694.89    8.69    617.42
# 7    2017         122,745.30    40,711.86     134.70   16.03    664.24
# 8    2018         117,521.10    41,394.96     570.78  201.76    625.19
# 9    2019         123,790.75    41,256.29     344.29  215.35    608.57
# 10  Total       1,124,844.31   381,594.32  18,600.29  475.96  6,135.80
#
#        Eólica Geotérmica       Hidro Carbón Mineral  ...      G.L.P  \
# ...

# %%
df_energia.replace("?", np.nan, inplace = True)
df_energia.head(10)
# Out:
#     Año Importaciones (TJ) TotalGenElec   Térmica   Solar Biomasa    Eólica  \
# 0  2010         104,818.94    34,499.95  2,308.23    0.93  521.41  1,291.23
# 1  2011         105,991.40    35,393.24  3,108.03    1.73  500.37  1,492.11
# 2  2012         105,521.89    36,627.60  2,989.02    4.67  643.04  1,902.18
# 3  2013         108,967.28    36,842.78  4,305.59    8.80  659.94  1,744.45
# 4  2014         112,928.31    36,778.79  3,755.53    8.88  650.24  2,645.11
# 5  2015         107,389.30    38,921.94    389.23    9.12  645.38  3,886.23
# 6  2016         115,170.04    39,166.91    694.89    8.69  617.42  4,130.25
# 7  2017         122,745.30    40,711.86    134.70   16.03  664.24  4,635.64
# 8  2018         117,521.10    41,394.96    570.78  201.76  625.19  6,475.95
# 9  2019         123,790.75    41,256.29    344.29  215.35  608.57  6,466.84
#
#   Geotérmica      Hidro Carbón Mineral  ...     G.L.P Gasolina Regular  \
# ...

# %% [markdown]
# <h5>2.2 Contar valores faltantes por columna</h5>

# %%
valoresPerdidos = df_energia.isnull()
valoresPerdidos
# Out:
#       Año  Importaciones (TJ)  TotalGenElec  Térmica  Solar  Biomasa  Eólica  \
# 0   False               False         False    False  False    False   False
# 1   False               False         False    False  False    False   False
# 2   False               False         False    False  False    False   False
# 3   False               False         False    False  False    False   False
# 4   False               False         False    False  False    False   False
# 5   False               False         False    False  False    False   False
# 6   False               False         False    False  False    False   False
# 7   False               False         False    False  False    False   False
# 8   False               False         False    False  False    False   False
# 9   False               False         False    False  False    False   False
# 10  False               False         False    False  False    False   False
#
# ...

# %%
for column in valoresPerdidos.columns.values.tolist() :
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# Año
# False    11
# Name: Año, dtype: int64
#
# Importaciones (TJ)
# False    11
# Name: Importaciones (TJ), dtype: int64
#
# TotalGenElec
# False    11
# Name: TotalGenElec, dtype: int64
#
# Térmica
# False    11
# Name: Térmica, dtype: int64
#
# Solar
# False    11
# Name: Solar, dtype: int64
#
# Biomasa
# False    11
# Name: Biomasa, dtype: int64
#
# Eólica
# False    11
# Name: Eólica, dtype: int64
#
# Geotérmica
# False    11
# Name: Geotérmica, dtype: int64
#
# Hidro
# False    11
# Name: Hidro, dtype: int64
#
# Carbón Mineral
# False    11
# Name: Carbón Mineral, dtype: int64
#
# Coque
# False    11
# Name: Coque, dtype: int64
#
# Leña
# False    11
# Name: Leña, dtype: int64
#
# Bagazo
# False    11
# Name: Bagazo, dtype: int64
#
# Otros Res. Veg.
# False    11
# Name: Otros Res. Veg., dtype: int64
#
# Carbón Vegetal
# False    11
# Name: Carbón Vegetal, dtype: int64
#
# Casc. de Café
# False    11
# Name: Casc. de Café, dtype: int64
#
# Biogas
# False    11
# ...

# %% [markdown]
# <h5>2.3 Imputar datos numericos</h5>

# %% [markdown]
# <p>No aparecen datos numericos faltantes</p>

# %% [markdown]
# <h5>2.4 Imputar datos tipo caracter</h5>

# %% [markdown]
# <p>No aparecen datos tipo caracter faltantes</p>

# %% [markdown]
# <h5>2.5 Eliminar valores faltantes</h5>

# %% [markdown]
# <p>No quedan datos faltantes</p>

# %% [markdown]
# <h2 Style="color:#1E90FF">3. Estandarizacion de datos</h2>
#
# <p>Pasos de la etapa</p>
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario</li>
#     <li>Convertir valores en función de la interpretación</li>
#     <li>Normalizar datos para que sus valores queden entre cero y uno</li>
#     <li>Agrupar datos (Binning)</li>
#     <li>Eliminar filas o columas con valores faltantes</li>

# %% [markdown]
# <h5>3.1 Verificar el dominio de las variables</h5>

# %%
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)     object
# TotalGenElec           object
# Térmica                object
# Solar                 float64
# Biomasa                object
# Eólica                 object
# Geotérmica             object
# Hidro                  object
# Carbón Mineral         object
# Coque                  object
# Leña                   object
# Bagazo                 object
# Otros Res. Veg.        object
# Carbón Vegetal        float64
# Casc. de Café          object
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia=df_energia.replace(",","", regex=True)  #Las comas me daban el problema que no me permitia transformar de tipo object a float, busqué esta fórmula para eliminarlas.

# %%
df_energia
# Out:
#       Año Importaciones (TJ) TotalGenElec   Térmica   Solar  Biomasa  \
# 0    2010          104818.94     34499.95   2308.23    0.93   521.41
# 1    2011          105991.40     35393.24   3108.03    1.73   500.37
# 2    2012          105521.89     36627.60   2989.02    4.67   643.04
# 3    2013          108967.28     36842.78   4305.59    8.80   659.94
# 4    2014          112928.31     36778.79   3755.53    8.88   650.24
# 5    2015          107389.30     38921.94    389.23    9.12   645.38
# 6    2016          115170.04     39166.91    694.89    8.69   617.42
# 7    2017          122745.30     40711.86    134.70   16.03   664.24
# 8    2018          117521.10     41394.96    570.78  201.76   625.19
# 9    2019          123790.75     41256.29    344.29  215.35   608.57
# 10  Total         1124844.31    381594.32  18600.29  475.96  6135.80
#
#       Eólica Geotérmica      Hidro Carbón Mineral  ...     G.L.P  \
# 0    1291.23    4233.89   26144.25          29.89  ...   5404.43
# ...

# %%
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)     object
# TotalGenElec           object
# Térmica                object
# Solar                 float64
# Biomasa                object
# Eólica                 object
# Geotérmica             object
# Hidro                  object
# Carbón Mineral         object
# Coque                  object
# Leña                   object
# Bagazo                 object
# Otros Res. Veg.        object
# Carbón Vegetal        float64
# Casc. de Café          object
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["Importaciones (TJ)"]]=df_energia[["Importaciones (TJ)"]].astype("float")

# %%
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec           object
# Térmica                object
# Solar                 float64
# Biomasa                object
# Eólica                 object
# Geotérmica             object
# Hidro                  object
# Carbón Mineral         object
# Coque                  object
# Leña                   object
# Bagazo                 object
# Otros Res. Veg.        object
# Carbón Vegetal        float64
# Casc. de Café          object
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["TotalGenElec","Térmica"]]=df_energia[["TotalGenElec","Térmica"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa                object
# Eólica                 object
# Geotérmica             object
# Hidro                  object
# Carbón Mineral         object
# Coque                  object
# Leña                   object
# Bagazo                 object
# Otros Res. Veg.        object
# Carbón Vegetal        float64
# Casc. de Café          object
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["Biomasa","Eólica","Geotérmica","Hidro","Carbón Mineral"]]=df_energia[["Biomasa","Eólica","Geotérmica","Hidro","Carbón Mineral"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                  object
# Leña                   object
# Bagazo                 object
# Otros Res. Veg.        object
# Carbón Vegetal        float64
# Casc. de Café          object
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["Coque","Leña","Bagazo","Otros Res. Veg.","Casc. de Café"]]=df_energia[["Coque","Leña","Bagazo","Otros Res. Veg.","Casc. de Café"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                 float64
# Leña                  float64
# Bagazo                float64
# Otros Res. Veg.       float64
# Carbón Vegetal        float64
# Casc. de Café         float64
# Biogas                 object
# Electricidad           object
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["Electricidad"]]=df_energia[["Electricidad"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                 float64
# Leña                  float64
# Bagazo                float64
# Otros Res. Veg.       float64
# Carbón Vegetal        float64
# Casc. de Café         float64
# Biogas                 object
# Electricidad          float64
# G.L.P                  object
# Gasolina Regular       object
# Gasolina Súper         object
# Kerosene               object
# Jet Fuel               object
# Av-Gas                float64
# Diesel                 object
# Gasoleo                object
# Fuel Oil               object
# Total                  object
# dtype: object

# %%
df_energia[["Gasolina Regular","Gasolina Súper","Kerosene","Jet Fuel","Diesel","Gasoleo","Fuel Oil","Total"]]=df_energia[["Gasolina Regular","Gasolina Súper","Kerosene","Jet Fuel","Diesel","Gasoleo","Fuel Oil","Total"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                 float64
# Leña                  float64
# Bagazo                float64
# Otros Res. Veg.       float64
# Carbón Vegetal        float64
# Casc. de Café         float64
# Biogas                 object
# Electricidad          float64
# G.L.P                  object
# Gasolina Regular      float64
# Gasolina Súper        float64
# Kerosene              float64
# Jet Fuel              float64
# Av-Gas                float64
# Diesel                float64
# Gasoleo               float64
# Fuel Oil              float64
# Total                 float64
# dtype: object

# %%
df_energia[["G.L.P"]]=df_energia[["G.L.P"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                 float64
# Leña                  float64
# Bagazo                float64
# Otros Res. Veg.       float64
# Carbón Vegetal        float64
# Casc. de Café         float64
# Biogas                 object
# Electricidad          float64
# G.L.P                 float64
# Gasolina Regular      float64
# Gasolina Súper        float64
# Kerosene              float64
# Jet Fuel              float64
# Av-Gas                float64
# Diesel                float64
# Gasoleo               float64
# Fuel Oil              float64
# Total                 float64
# dtype: object

# %%
df_energia["Biogas"]
# Out:
# 0         -
# 1      2.99
# 2      3.03
# 3      3.03
# 4      3.03
# 5      3.03
# 6      3.03
# 7      3.03
# 8      3.03
# 9      3.03
# 10    27.23
# Name: Biogas, dtype: object

# %%
df_energia["Biogas"].value_counts()
# Out:
# 3.03     8
# -        1
# 2.99     1
# 27.23    1
# Name: Biogas, dtype: int64

# %%
df_energia["Biogas"].replace("-", "0", inplace=True) #en esta columna había un dato que no era númerico, no se hicieron todas las transformaciones juntas porque estaba buscando cual columna era el problema.Se reemplaza con 0 porque dicho valor es nulo, en dicho año no debió haber registro de la producción.
df_energia["Biogas"].value_counts()
# Out:
# 3.03     8
# 0        1
# 2.99     1
# 27.23    1
# Name: Biogas, dtype: int64

# %%
df_energia[["Biogas"]]=df_energia[["Biogas"]].astype("float")
df_energia.dtypes
# Out:
# Año                    object
# Importaciones (TJ)    float64
# TotalGenElec          float64
# Térmica               float64
# Solar                 float64
# Biomasa               float64
# Eólica                float64
# Geotérmica            float64
# Hidro                 float64
# Carbón Mineral        float64
# Coque                 float64
# Leña                  float64
# Bagazo                float64
# Otros Res. Veg.       float64
# Carbón Vegetal        float64
# Casc. de Café         float64
# Biogas                float64
# Electricidad          float64
# G.L.P                 float64
# Gasolina Regular      float64
# Gasolina Súper        float64
# Kerosene              float64
# Jet Fuel              float64
# Av-Gas                float64
# Diesel                float64
# Gasoleo               float64
# Fuel Oil              float64
# Total                 float64
# dtype: object

# %% [markdown]
# <h5>3.2 Convertir valores en función de su interpretación</h5>

# %% [markdown]
# <p>Todos los datos estan en TeraJoules</p>

# %% [markdown]
# <h5>3.3 Normalización de datos</h5>

# %%
df_energia
# Out:
#       Año  Importaciones (TJ)  TotalGenElec   Térmica   Solar  Biomasa  \
# 0    2010           104818.94      34499.95   2308.23    0.93   521.41
# 1    2011           105991.40      35393.24   3108.03    1.73   500.37
# 2    2012           105521.89      36627.60   2989.02    4.67   643.04
# 3    2013           108967.28      36842.78   4305.59    8.80   659.94
# 4    2014           112928.31      36778.79   3755.53    8.88   650.24
# 5    2015           107389.30      38921.94    389.23    9.12   645.38
# 6    2016           115170.04      39166.91    694.89    8.69   617.42
# 7    2017           122745.30      40711.86    134.70   16.03   664.24
# 8    2018           117521.10      41394.96    570.78  201.76   625.19
# 9    2019           123790.75      41256.29    344.29  215.35   608.57
# 10  Total          1124844.31     381594.32  18600.29  475.96  6135.80
#
#       Eólica  Geotérmica      Hidro  Carbón Mineral  ...     G.L.P  \
# ...

# %%
df_energia_n=df_energia #se crea nuevo set previo a eliminación por si se da un error
df_energia_n
# Out:
#       Año  Importaciones (TJ)  TotalGenElec   Térmica   Solar  Biomasa  \
# 0    2010           104818.94      34499.95   2308.23    0.93   521.41
# 1    2011           105991.40      35393.24   3108.03    1.73   500.37
# 2    2012           105521.89      36627.60   2989.02    4.67   643.04
# 3    2013           108967.28      36842.78   4305.59    8.80   659.94
# 4    2014           112928.31      36778.79   3755.53    8.88   650.24
# 5    2015           107389.30      38921.94    389.23    9.12   645.38
# 6    2016           115170.04      39166.91    694.89    8.69   617.42
# 7    2017           122745.30      40711.86    134.70   16.03   664.24
# 8    2018           117521.10      41394.96    570.78  201.76   625.19
# 9    2019           123790.75      41256.29    344.29  215.35   608.57
# 10  Total          1124844.31     381594.32  18600.29  475.96  6135.80
#
#       Eólica  Geotérmica      Hidro  Carbón Mineral  ...     G.L.P  \
# ...

# %%
df_energia_n=df_energia_n.drop(10)  #se elimina fila de total, ya que afectaría normalización por incluir los demás valores
df_energia_n
# Out:
#     Año  Importaciones (TJ)  TotalGenElec  Térmica   Solar  Biomasa   Eólica  \
# 0  2010           104818.94      34499.95  2308.23    0.93   521.41  1291.23
# 1  2011           105991.40      35393.24  3108.03    1.73   500.37  1492.11
# 2  2012           105521.89      36627.60  2989.02    4.67   643.04  1902.18
# 3  2013           108967.28      36842.78  4305.59    8.80   659.94  1744.45
# 4  2014           112928.31      36778.79  3755.53    8.88   650.24  2645.11
# 5  2015           107389.30      38921.94   389.23    9.12   645.38  3886.23
# 6  2016           115170.04      39166.91   694.89    8.69   617.42  4130.25
# 7  2017           122745.30      40711.86   134.70   16.03   664.24  4635.64
# 8  2018           117521.10      41394.96   570.78  201.76   625.19  6475.95
# 9  2019           123790.75      41256.29   344.29  215.35   608.57  6466.84
#
#    Geotérmica     Hidro  Carbón Mineral  ...    G.L.P  Gasolina Regular  \
# ...

# %%
df_energia_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Año                 10 non-null     object
#  1   Importaciones (TJ)  10 non-null     float64
#  2   TotalGenElec        10 non-null     float64
#  3   Térmica             10 non-null     float64
#  4   Solar               10 non-null     float64
#  5   Biomasa             10 non-null     float64
#  6   Eólica              10 non-null     float64
#  7   Geotérmica          10 non-null     float64
#  8   Hidro               10 non-null     float64
#  9   Carbón Mineral      10 non-null     float64
#  10  Coque               10 non-null     float64
#  11  Leña                10 non-null     float64
#  12  Bagazo              10 non-null     float64
#  13  Otros Res. Veg.     10 non-null     float64
#  14  Carbón Vegetal      10 non-null     float64
# ...

# %%
dfTemp=df_energia_n[["Coque","Leña","Bagazo","Otros Res. Veg.","Casc. de Café"]]  #este paso de normalización se realiza según lo visto en clase pero no se reflejara en datos al ser un data temporal solo sobre algunos datos como ejemplo.
dfTemp
# Out:
#      Coque      Leña    Bagazo  Otros Res. Veg.  Casc. de Café
# 0  2675.36  13998.14   9836.32          4395.70         375.26
# 1  3717.92  12839.58   7729.44          4448.78         407.07
# 2  3382.79  12161.88   8088.95          4385.46         461.19
# 3  3359.27  12059.79   9864.93          4161.97         461.19
# 4  3288.28  11066.46  10318.32          4360.37         371.96
# 5  3211.70  10825.70  10072.36          3789.58         371.37
# 6  3493.96  10170.89  10072.36          3742.20         437.15
# 7  3786.46  10211.16   9359.19          3329.99         400.44
# 8  3534.58   8603.49   9134.57          3224.83         347.55
# 9  1728.44   8582.54   9060.66          3258.67         372.59

# %%
dfTemp["Coque"]=dfTemp["Coque"]/dfTemp["Coque"].max()
dfTemp["Leña"]=dfTemp["Leña"]/dfTemp["Leña"].max()
dfTemp["Bagazo"]=dfTemp["Bagazo"]/dfTemp["Bagazo"].max()
dfTemp["Otros Res. Veg."]=dfTemp["Otros Res. Veg."]/dfTemp["Otros Res. Veg."].max()
dfTemp["Casc. de Café"]=dfTemp["Casc. de Café"]/dfTemp["Casc. de Café"].max()
dfTemp
# Out:
# C:\Users\josel\AppData\Local\Temp\ipykernel_16244\959873299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTemp["Coque"]=dfTemp["Coque"]/dfTemp["Coque"].max()
# C:\Users\josel\AppData\Local\Temp\ipykernel_16244\959873299.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTemp["Leña"]=dfTemp["Leña"]/dfTemp["Leña"].max()
# C:\Users\josel\AppData\Local\Temp\ipykernel_16244\959873299.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# <h5>3.4 Binning</h5>

# %%
cat=np.linspace(min(df_energia["Importaciones (TJ)"]),max(df_energia["Importaciones (TJ)"]),4)
cat
# Out:
# array([ 104818.94      ,  444827.39666667,  784835.85333333,
#        1124844.31      ])

# %% [markdown]
# <li>Los datos son muy pocos para realizar un binning de utilidad</li>

# %% [markdown]
# <h2 Style="color:#1E90FF">4. Visualización de datos</h2>
#
# <p>Pasos de la etapa</p>
# <ol>
#     <li>Responder las preguntas de negocio</li>
#     <li>Liberar conocimiento</li>
#     <li>Generar informe de negocio</li>

# %%
df_energia_n.columns
# Out:
# Index(['Año', 'Importaciones (TJ)', 'TotalGenElec', 'Térmica', 'Solar',
#        'Biomasa', 'Eólica', 'Geotérmica', 'Hidro', 'Carbón Mineral', 'Coque',
#        'Leña', 'Bagazo', 'Otros Res. Veg.', 'Carbón Vegetal', 'Casc. de Café',
#        'Biogas', 'Electricidad', 'G.L.P', 'Gasolina Regular', 'Gasolina Súper',
#        'Kerosene', 'Jet Fuel', 'Av-Gas', 'Diesel', 'Gasoleo', 'Fuel Oil',
#        'Total'],
#       dtype='object')

# %%
df_energia["Año"].tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0      2010
# 1      2011
# 2      2012
# 3      2013
# 4      2014
# 5      2015
# 6      2016
# 7      2017
# 8      2018
# 9      2019
# 10    Total
# Name: Año, dtype: object>

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = df_energia_n["Año"].tolist()
TotalGenElec = df_energia_n["TotalGenElec"].tolist()
Electricidad = df_energia_n["Electricidad"].tolist()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, TotalGenElec, width, label='Electricidad generada')
rects2 = ax.bar(x + width/2, Electricidad, width, label='Electricidad consumida')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Terajoules')
ax.set_title('Generación vs Consumo de Electricidad')
ax.set_xticks(x, labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = df_energia_n["Año"].tolist()
TotalGenElec = df_energia_n["TotalGenElec"].tolist()
ImportaciónDeEnergia = df_energia_n["Importaciones (TJ)"].tolist()
TotalDeConsumo = df_energia_n["Total"].tolist()

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, TotalGenElec, width, label='Electricidad generada')
rects2 = ax.bar(x + width, Electricidad, width, label='ImportaciónDeEnergia')
rects3 = ax.bar(x + width/6, TotalDeConsumo, width, label='TotalDeConsumo')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Terajoules')
ax.set_title('Generación vs Importación')
ax.set_xticks(x, labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = df_energia_n["Año"].tolist()
Solar = df_energia_n["Solar"].tolist()
Gasolina = df_energia_n["Gasolina Regular"].tolist()
Electrica = df_energia_n["Electricidad"].tolist()

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, TotalGenElec, width, label='Solar')
rects2 = ax.bar(x + width, Electricidad, width, label='Gasolina')
rects3 = ax.bar(x + width/6, TotalDeConsumo, width, label='Electrica')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Terajoules')
ax.set_title('Generación vs Importación')
ax.set_xticks(x, labels)
ax.legend()

fig.tight_layout()

plt.show()

# %% [markdown]
# <p>Conclusión</p>
# <ol>
#     <li>Se considera el set de datos y utilizacióm del mismo no fue apropiado para respondar la pregunta de negocio, al visualizar los datos se notan problemas por falta de congruencia, por lo que la ejecución presenta defectos. No se considera viable buscar respuesta a la pregunta con el análisis realizado</li>
